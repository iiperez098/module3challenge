# %%
#import libraries
import pandas as pd 
from pathlib import Path 
from matplotlib import pyplot as plt

# %%
#import using read_csv
bitstamp_df = pd.read_csv(
    Path("c:/users/mensg/fintech/mod3/challengemod3/starter_code/resources/bitstamp.csv"),
    index_col="Timestamp",
    parse_dates=True,
    infer_datetime_format=True
)

# %%
#print out head and tail
bitstamp_df.head()
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %%
bitstamp_df.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6935.01  6939.07  6922.56  $6922.56    1.044354
# 2018-03-31 23:56:00  6922.02  6922.02  6918.00  $6920.32    3.069539
# 2018-03-31 23:57:00  6920.33  6936.42  6920.33  $6934.72   28.239049
# 2018-03-31 23:58:00  6927.65  6929.42  6927.65  $6927.65    0.839507
# 2018-03-31 23:59:00  6929.98  6929.98  6928.00  $6928.01    0.209363
#
#                         USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00    7240.034602     6932.550078
# 2018-03-31 23:56:00   21245.076275     6921.260233
# 2018-03-31 23:57:00  195789.408220     6933.286106
# 2018-03-31 23:58:00    5817.007705     6929.080007
# 2018-03-31 23:59:00    1450.735763     6929.289993

# %%
#Import using read_csv
coinbase_df = pd.read_csv(
    Path("c:/users/mensg/fintech/mod3/challengemod3/starter_code/resources/coinbase.csv"),
    index_col="Timestamp",
    parse_dates=True,
    infer_datetime_format=True
)

# %%
#Print out head and tail
coinbase_df.head()
# Out:
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %%
coinbase_df.tail()
# Out:
#                         Open     High      Low     Close  BTC Volume  \
# Timestamp
# 2018-03-31 23:55:00  6945.20  6948.06  6930.00   $6930.0    5.802288
# 2018-03-31 23:56:00  6930.00  6930.01  6930.00  $6930.01    0.625053
# 2018-03-31 23:57:00  6930.01  6933.91  6930.01  $6933.91    0.776431
# 2018-03-31 23:58:00  6933.91  6938.00  6933.90  $6937.31    0.133413
# 2018-03-31 23:59:00  6937.30  6937.30  6931.09   $6934.0    1.012720
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-03-31 23:55:00  40243.918480     6935.869979
# 2018-03-31 23:56:00   4331.620701     6930.005567
# 2018-03-31 23:57:00   5382.532162     6932.405747
# 2018-03-31 23:58:00    925.356547     6936.048538
# 2018-03-31 23:59:00   7022.275088     6934.070316

# %%
#Drop all NaN values in DataFrame
bitstamp_df = bitstamp_df.dropna()

# %%
#use str.replace to remove dollar signs
bitstamp_df.loc[:, "Close"] = bitstamp_df.loc[:,"Close"].str.replace("$", "")
# Out:
# <ipython-input-9-850256c5d2d4>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bitstamp_df.loc[:, "Close"] = bitstamp_df.loc[:,"Close"].str.replace("$", "")

# %%
bitstamp_df.head()
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# 2018-01-01 00:03:00  97856.416478    13623.361128
# 2018-01-01 00:04:00  14582.660932    13632.923329

# %%
#convert data type to float
bitstamp_df.loc[:, "Close"] = bitstamp_df.loc[:,"Close"].astype("float")

# %%
#find missing values and drop if necessary
bitstamp_df.isnull().sum()
# Out:
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %%
#Drop all NaN values in DataFrame
coinbase_df = coinbase_df.dropna()

# %%
#use str.replace to remove dollar signs
coinbase_df.loc[:, "Close"] = coinbase_df.loc[:,"Close"].str.replace("$", "")
# Out:
# <ipython-input-14-b56d255412ef>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   coinbase_df.loc[:, "Close"] = coinbase_df.loc[:,"Close"].str.replace("$", "")

# %%
coinbase_df.head()
# Out:
#                          Open      High       Low     Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# 2018-01-01 00:03:00  221413.64182    13560.332806
# 2018-01-01 00:04:00  135141.26944    13574.719401

# %%
#convert data type to float
coinbase_df.loc[:, "Close"] = coinbase_df.loc[:,"Close"].astype("float")

# %%
#find missing values and drop if necessary
coinbase_df.duplicated().sum()
# Out:
# 0

# %%
#close and timestamp slice
bitstamp_df_sliced = bitstamp_df.loc[:,"Close"]
bitstamp_df_sliced.head()
# Out:
# Timestamp
# 2018-01-01 00:00:00    13646.48
# 2018-01-01 00:01:00    13658.75
# 2018-01-01 00:02:00    13610.22
# 2018-01-01 00:03:00    13639.09
# 2018-01-01 00:04:00    13620.00
# Name: Close, dtype: float64

# %%
coinbase_df_sliced = coinbase_df.loc[:, "Close"]
coinbase_df_sliced.head()
# Out:
# Timestamp
# 2018-01-01 00:00:00    13608.49
# 2018-01-01 00:01:00    13601.66
# 2018-01-01 00:02:00    13580.00
# 2018-01-01 00:03:00    13550.34
# 2018-01-01 00:04:00    13583.44
# Name: Close, dtype: float64

# %%
#summary for each 
bitstamp_df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  129067.000000  129067.000000  129067.000000  129067.000000
# mean    10459.993683   10472.970114   10446.214703   10459.842453
# std      2315.909269    2318.929342    2312.331601    2315.976088
# min      5945.950000    5975.060000    5920.720000    5944.000000
# 25%      8613.985000    8621.655000    8604.440000    8613.370000
# 50%     10145.300000   10156.410000   10131.740000   10145.950000
# 75%     11444.455000   11453.990000   11431.970000   11444.810000
# max     17234.980000   17234.990000   17214.960000   17234.980000
#
#           BTC Volume    USD Volume  Weighted Price
# count  129067.000000  1.290670e+05   129067.000000
# mean       11.792878  1.177496e+05    10459.384448
# std        21.799938  2.070551e+05     2315.723480
# min         0.000039  3.333436e-01     5949.997212
# 25%         1.711874  1.773244e+04     8613.587020
# 50%         4.994095  5.188050e+04    10144.740411
# ...

# %%
coinbase_df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  129322.000000  129322.000000  129322.000000  129322.000000
# mean    10449.213185   10456.118514   10441.872248   10449.140958
# std      2317.194653    2317.710389    2316.570594    2317.197419
# min      5882.300000    5907.280000    5873.000000    5882.310000
# 25%      8609.230000    8613.872500    8603.505000    8609.230000
# 50%     10137.440000   10145.900000   10127.880000   10137.440000
# 75%     11397.522500   11400.000000   11390.000000   11397.237500
# max     17178.000000   17178.000000   17177.990000   17177.990000
#
#           BTC Volume    USD Volume  Weighted Price
# count  129322.000000  1.293220e+05   129322.000000
# mean       15.666556  1.572565e+05    10448.964130
# std        27.481647  2.667879e+05     2317.167139
# min         0.000442  6.699174e+00     5883.394912
# 25%         2.999125  3.071222e+04     8609.135020
# 50%         7.092572  7.461366e+04    10136.035004
# ...

# %%
#line plot for each
bitstamp_df['Close'].plot(figsize=(10,5), title="BitStamp", color="blue")
# Out:
# <AxesSubplot:title={'center':'BitStamp'}, xlabel='Timestamp'>

# %%
coinbase_df['Close'].plot(figsize=(10,5), title="CoinBase", color="orange")
# Out:
# <AxesSubplot:title={'center':'CoinBase'}, xlabel='Timestamp'>

# %%
#overlay plot
bitstamp_df['Close'].plot(legend=True, figsize=(15, 7), title="BitStamp and CoinBase Overlay Plot", color="blue", label="BitStamp")
coinbase_df['Close'].plot(legend=True, figsize=(15, 7), color="orange", label="Coinbase")
# Out:
# <AxesSubplot:title={'center':'BitStamp and CoinBase Overlay Plot'}, xlabel='Timestamp'>

# %%
#one month early
bitstamp_df['Close'].loc['2018-01-01' : '2018-02-01'].plot(
    legend=True, figsize=(15, 10), title="January 2018", color="blue", label="BitStamp")
coinbase_df['Close'].loc['2018-01-01' : '2018-02-01'].plot(
    legend=True, figsize=(15, 10), color="orange", label="CoinBase")
# Out:
# <AxesSubplot:title={'center':'January 2018'}, xlabel='Timestamp'>

# %%
#one  month late
bitstamp_df['Close'].loc['2018-02-23' : '2018-03-23'].plot(
    legend=True, figsize=(15, 10), title="March 2018", color="blue", label="BitStamp")
coinbase_df['Close'].loc['2018-02-23' : '2018-03-23'].plot(
    legend=True, figsize=(15, 10), color="orange", label="CoinBase")
# Out:
# <AxesSubplot:title={'center':'March 2018'}, xlabel='Timestamp'>

# %%
#arbitrage early
#overlay plot
bitstamp_df['Close'].loc['2018-01-01'].plot(
    legend=True, figsize=(15, 10), title="January 2018", color="blue", label="BitStamp")
coinbase_df['Close'].loc['2018-01-01'].plot(
    legend=True, figsize=(15, 10), color="orange", label="CoinBase")
# Out:
# <AxesSubplot:title={'center':'January 2018'}, xlabel='Timestamp'>

# %%
#arbitrage
arbitrage_spread_early = coinbase_df['Close'].loc['2018-01-01'] - bitstamp_df['Close'].loc['2018-01-01']

# %%
#describe
arbitrage_spread_early.describe()
# Out:
# count    1421.000000
# mean        5.767368
# std        46.214511
# min      -142.000000
# 25%       -26.890000
# 50%         5.480000
# 75%        36.000000
# max       319.990000
# Name: Close, dtype: float64

# %%
#box plot
arbitrage_spread_early.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
#arbitrage mid
#overlay plot
bitstamp_df['Close'].loc['2018-02-01'].plot(
    legend=True, figsize=(15, 10), title="February 2018", color="blue", label="BitStamp")
coinbase_df['Close'].loc['2018-02-01'].plot(
    legend=True, figsize=(15, 10), color="orange", label="CoinBase")
# Out:
# <AxesSubplot:title={'center':'February 2018'}, xlabel='Timestamp'>

# %%
#arbitrage
arbitrage_spread_middle = coinbase_df['Close'].loc['2018-02-01'] - bitstamp_df['Close'].loc['2018-02-01']

# %%
#describe
arbitrage_spread_middle.describe()
# Out:
# count    1251.000000
# mean       13.956163
# std        25.420642
# min      -115.930000
# 25%        -0.960000
# 50%        13.860000
# 75%        30.795000
# max       125.180000
# Name: Close, dtype: float64

# %%
#box plot
arbitrage_spread_middle.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
#arbitrage late
#overlay plot 
bitstamp_df['Close'].loc['2018-03-23'].plot(
    legend=True, figsize=(15, 10), title="March 2018", color="blue", label="BitStamp")
coinbase_df['Close'].loc['2018-03-23'].plot(
    legend=True, figsize=(15, 10), color="orange", label="CoinBase")
# Out:
# <AxesSubplot:title={'center':'March 2018'}, xlabel='Timestamp'>

# %%
#arbitrage 
arbitrage_spread_late = coinbase_df['Close'].loc['2018-03-01'] - bitstamp_df['Close'].loc['2018-03-01']

# %%
#describe
arbitrage_spread_late.describe()
# Out:
# count    1425.00000
# mean      -14.45527
# std        12.52715
# min       -52.86000
# 25%       -22.87000
# 50%       -14.48000
# 75%        -6.12000
# max        41.10000
# Name: Close, dtype: float64

# %%
#boxplot
arbitrage_spread_late.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
'''measure the arbitrage spread by subtracting the lower-priced exchange from the higher-priced one. 
Then use a conditional statement where the spread is greater than zero.'''
# Out:
# 'measure the arbitrage spread by subtracting the lower-priced exchange from the higher-priced one. \nThen use a conditional statement where the spread is greater than zero.'

# %%
#early

# %%
arbitrage_spread_early = coinbase_df['Close'].loc['2018-01-01'] - bitstamp_df['Close'].loc['2018-01-01']

# %%
spread_return_early = arbitrage_spread_early[arbitrage_spread_early>0] / bitstamp_df['Close'].loc['2018-01-01']
arbitrage_spread_early.describe()
# Out:
# count    1421.000000
# mean        5.767368
# std        46.214511
# min      -142.000000
# 25%       -26.890000
# 50%         5.480000
# 75%        36.000000
# max       319.990000
# Name: Close, dtype: float64

# %%
#middle

# %%
arbitrage_spread_middle = coinbase_df['Close'].loc['2018-02-01'] - bitstamp_df['Close'].loc['2018-02-01']

# %%
spread_return_middle = arbitrage_spread_middle[arbitrage_spread_middle>0] / bitstamp_df['Close'].loc['2018-02-01']
arbitrage_spread_middle.describe()
# Out:
# count    1251.000000
# mean       13.956163
# std        25.420642
# min      -115.930000
# 25%        -0.960000
# 50%        13.860000
# 75%        30.795000
# max       125.180000
# Name: Close, dtype: float64

# %%
#late

# %%
arbitrage_spread_late = coinbase_df['Close'].loc['2018-03-23'] - bitstamp_df['Close'].loc['2018-03-23']

# %%
spread_return_late = arbitrage_spread_late[arbitrage_spread_late>0] / bitstamp_df['Close'].loc['2018-03-23']
arbitrage_spread_late.describe()
# Out:
# count    1434.000000
# mean       -4.552434
# std         8.191096
# min       -38.230000
# 25%       -10.000000
# 50%        -4.300000
# 75%         0.652500
# max        32.000000
# Name: Close, dtype: float64

# %%
#return early
profitable_trades_early = spread_return_early[spread_return_early > .01]
profitable_trades_early.head(10)
# Out:
# Timestamp
# 2018-01-01 09:10:00    0.011455
# 2018-01-01 23:25:00    0.022465
# 2018-01-01 23:26:00    0.024616
# 2018-01-01 23:27:00    0.015948
# 2018-01-01 23:28:00    0.011261
# 2018-01-01 23:29:00    0.012001
# 2018-01-01 23:31:00    0.010427
# Name: Close, dtype: float64

# %%
profitable_trades_early.describe()
# Out:
# count    7.000000
# mean     0.015453
# std      0.005833
# min      0.010427
# 25%      0.011358
# 50%      0.012001
# 75%      0.019207
# max      0.024616
# Name: Close, dtype: float64

# %%
#return middle
profitable_trades_middle = spread_return_middle[spread_return_middle > .01]
profitable_trades_middle.head(10)
# Out:
# Timestamp
# 2018-02-01 09:47:00    0.013529
# Name: Close, dtype: float64

# %%
profitable_trades_middle.describe()
# Out:
# count    1.000000
# mean     0.013529
# std           NaN
# min      0.013529
# 25%      0.013529
# 50%      0.013529
# 75%      0.013529
# max      0.013529
# Name: Close, dtype: float64

# %%
#return late
profitable_trades_late = spread_return_late[spread_return_late > .01]
profitable_trades_late.head(10)
# Out:
# Series([], Name: Close, dtype: float64)

# %%
profitable_trades_late.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
profitable_trades_early.plot(figsize=(10, 5), title="profit early", color="blue")
# Out:
# <AxesSubplot:title={'center':'profit early'}, xlabel='Timestamp'>

# %%
profitable_trades_middle.plot(figsize=(10, 5), title="profit middle", color="blue")
# Out:
# <AxesSubplot:title={'center':'profit middle'}, xlabel='Timestamp'>

# %%
profitable_trades_late.plot(figsize=(10, 5), title="profit late", color="blue")
# Out:
# <AxesSubplot:title={'center':'profit late'}, xlabel='Timestamp'>

# %%
profit_early = profitable_trades_early * bitstamp_df['Close'].loc['2018-01-01']
profit_early
# Out:
# Timestamp
# 2018-01-01 00:00:00   NaN
# 2018-01-01 00:01:00   NaN
# 2018-01-01 00:02:00   NaN
# 2018-01-01 00:03:00   NaN
# 2018-01-01 00:04:00   NaN
#                        ..
# 2018-01-01 23:55:00   NaN
# 2018-01-01 23:56:00   NaN
# 2018-01-01 23:57:00   NaN
# 2018-01-01 23:58:00   NaN
# 2018-01-01 23:59:00   NaN
# Name: Close, Length: 1421, dtype: float64

# %%
profit_middle = profitable_trades_middle * bitstamp_df['Close'].loc['2018-02-01']
profit_middle
# Out:
# Timestamp
# 2018-02-01 00:00:00   NaN
# 2018-02-01 00:01:00   NaN
# 2018-02-01 00:02:00   NaN
# 2018-02-01 00:03:00   NaN
# 2018-02-01 00:04:00   NaN
#                        ..
# 2018-02-01 23:55:00   NaN
# 2018-02-01 23:56:00   NaN
# 2018-02-01 23:57:00   NaN
# 2018-02-01 23:58:00   NaN
# 2018-02-01 23:59:00   NaN
# Name: Close, Length: 1437, dtype: float64

# %%
profit_late = profitable_trades_late * bitstamp_df['Close'].loc['2018-03-23']
profit_late
# Out:
# Timestamp
# 2018-03-23 00:00:00   NaN
# 2018-03-23 00:01:00   NaN
# 2018-03-23 00:02:00   NaN
# 2018-03-23 00:03:00   NaN
# 2018-03-23 00:04:00   NaN
#                        ..
# 2018-03-23 23:55:00   NaN
# 2018-03-23 23:56:00   NaN
# 2018-03-23 23:57:00   NaN
# 2018-03-23 23:58:00   NaN
# 2018-03-23 23:59:00   NaN
# Name: Close, Length: 1434, dtype: float64

# %%
cumulative_profit_early = profit_early.cumsum()
cumulative_profit_early.plot(figsize=(10, 7), title="Early Profits")
# Out:
# <AxesSubplot:title={'center':'Early Profits'}, xlabel='Timestamp'>

# %%
cumulative_profit_middle = profit_middle.cumsum()
cumulative_profit_middle.plot(figsize=(10, 7), title="Middle Profits")
# Out:
# <AxesSubplot:title={'center':'Middle Profits'}, xlabel='Timestamp'>

# %%
cumulative_profit_late = profit_late.cumsum()
cumulative_profit_late.plot(figsize=(10, 7), title="Late Profits")
# Out:
# <AxesSubplot:title={'center':'Late Profits'}, xlabel='Timestamp'>

# %%
'''Create Your Analysis Report (20 points)
To receive all points, your report must include:
Assumptions or discoveries that you made during the analysis (10 points)
Summary tables and calculations (5 points)
Visualizations (5 points)'''
# Out:
# 'Create Your Analysis Report (20 points)\nTo receive all points, your report must include:\nAssumptions or discoveries that you made during the analysis (10 points)\nSummary tables and calculations (5 points)\nVisualizations (5 points)'

# %%
'''
With pandas and plotlib i've managed to learn for to do financial computation for bitstamp and coinbase.
Also I was able to find the arbirage returns between the both for arbitrage trading.
The tables show brief information of the summary information and the charts show the results over a given time.
The calculations returned give us the returns based on arbitrage.
Visualization is an important part, = charts , because they allow us to visually see the data given and find patterns and more.



'''
# Out:
# "\nWith pandas and plotlib i've managed to learn for to do financial computation for bitstamp and coinbase.\nAlso I was able to find the arbirage returns between the both for arbitrage trading.\nThe tables show brief information of the summary information and the charts show the results over a given time.\nThe calculations returned give us the returns based on arbitrage.\nVisualization is an important part, = charts , because they allow us to visually see the data given and find patterns and more.\n\n\n\n"
